# %%
import pickle
import pandas as pd

# %%
version = 'v1'
geno_test_file = geno_test_file = '../processed_data/test_geno_with_8_m_avg_all_data_{}.pkl'.format(version)
geno_training_file = '../processed_data/tr_geno_with_8_m_avg_all_data_{}.pkl'.format(version)
geno_validation_file = '../processed_data/val_geno_with_8_m_avg_all_data_{}.pkl'.format(version)
geno_unqiue_test_file = '../processed_data/test_geno_unique_env_with_8_m_avg_all_data_{}.pkl'.format(version)

# %%
df = pd.DataFrame()

# %%
with open(geno_test_file, 'rb') as file:
    data = pickle.load(file)
    
data.shape
# Out:
# (12978, 4069)

# %%
df.append(data)
# Out:
# /var/folders/k7/ksx513m54v14grw8wqbbgj9w0000gn/T/ipykernel_62348/233211020.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(data)
#           CID  SID         GID  2A_15449240  2A_18359259  2A_2800711  \
# 0      568630   33  GID7400769     0.302138     0.438644    0.294080
# 1      568630   33  GID7400769     0.302138     0.438644    0.294080
# 2      568630   33  GID7400769     0.302138     0.438644    0.294080
# 3      568630   33  GID7400769     0.302138     0.438644    0.294080
# 4      568630   33  GID7400769     0.302138     0.438644    0.294080
# ...       ...  ...         ...          ...          ...         ...
# 12973  537330   26  GID6922446     0.202805     0.447300    0.209509
# 12974  537327   28  GID6922453     0.202805     0.447300    0.209509
# 12975  537327   28  GID6922453     0.202805     0.447300    0.209509
# ...

# %%
with open(geno_training_file, 'rb') as file:
    data = pickle.load(file)
    
data.shape

df.append(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/sheikhjubair/Documents/wheat_m1/code/all_data_combiner.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/sheikhjubair/Documents/wheat_m1/code/all_data_combiner.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> with open(geno_training_file, 'rb') as file:
#       <a href='vscode-notebook-cell:/Users/sheikhjubair/Documents/wheat_m1/code/all_data_combiner.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     data = pickle.load(file)
#       <a href='vscode-notebook-cell:/Users/sheikhjubair/Documents/wheat_m1/code/all_data_combiner.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> data.shape
#
# FileNotFoundError: [Errno 2] No such file or directory: '../processed_data/tr_geno_with_8_m_avg_all_data_v1.pkl'

# %%
with open(geno_validation_file, 'rb') as file:
    data = pickle.load(file)
    
data.shape

df.append(data)

# %%
with open(geno_unqiue_test_file, 'rb') as file:
    data = pickle.load(file)
    
data.shape

df.append(data)
